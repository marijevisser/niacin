# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import trompy as tp
from scipy import stats

# %%
# read in data
PATH_TO_WORKBOOK = Path("../data/")
EXCEL_WORKBOOK = "measurements_b3_2.xlsx"
rows, header = tp.metafilereader(PATH_TO_WORKBOOK / EXCEL_WORKBOOK, sheetname="bodyweight")
df = pd.DataFrame(rows, columns=header)

# %%
df
# Out:
#     Mouse     Sex          Diet Sucrose  2024-04-02 00:00:00  \
# 0   B3209  Female       control     Yes                 19.1
# 1   B3210  Female       control     Yes                 20.9
# 2   B3213  Female       control     Yes                 21.0
# 3   B3214  Female       control     Yes                 19.8
# 4   B3217  Female       control     Yes                 22.3
# 5   B3218  Female       control     Yes                 20.1
# 6   B3219  Female  experimental     Yes                 19.6
# 7   B3220  Female  experimental     Yes                 19.6
# 8   B3221  Female  experimental     Yes                 20.6
# 9   B3222  Female  experimental     Yes                 19.5
# 10  B3223  Female  experimental     Yes                 21.3
# 11  B3224  Female  experimental     Yes                 20.5
# 12  B3201  Female       control      No                 20.1
# 13  B3202  Female       control      No                 20.2
# 14  B3205  Female       control      No                 19.5
# 15  B3206  Female       control      No                 20.8
# 16  B3211  Female       control      No                 20.9
# 17  B3212  Female       control      No                 20.9
# 18  B3203  Female  experimental      No                 20.1
# 19  B3204  Female  experimental      No                 19.8
# 20  B3207  Female  experimental      No                 20.0
# 21  B3208  Female  experimental      No                 19.4
# 22  B3215  Female  experimental      No                 20.7
# 23  B3216  Female  experimental      No                 19.4
# 24  B3225    Male       control     Yes                 25.5
# 25  B3226    Male       control     Yes                 24.8
# 26  B3227    Male       control     Yes                 24.8
# 27  B3228    Male       control     Yes                 26.0
# 28  B3235    Male       control     Yes                 26.5
# 29  B3236    Male       control     Yes                 24.6
# 30  B3233    Male  experimental     Yes                 25.9
# 31  B3234    Male  experimental     Yes                 26.2
# 32  B3237    Male  experimental     Yes                 23.8
# 33  B3238    Male  experimental     Yes                 23.5
# 34  B3247    Male  experimental     Yes                 25.9
# 35  B3248    Male  experimental     Yes                 26.9
# 36  B3229    Male       control      No                 21.7
# 37  B3230    Male       control      No                 23.5
# 38  B3239    Male       control      No                 24.2
# 39  B3240    Male       control      No                 23.8
# 40  B3241    Male       control      No                 24.8
# 41  B3242    Male       control      No                 25.3
# 42  B3231    Male  experimental      No                 23.0
# 43  B3232    Male  experimental      No                 25.6
# 44  B3243    Male  experimental      No                 24.1
# 45  B3244    Male  experimental      No                 25.4
# 46  B3245    Male  experimental      No                 24.1
# 47  B3246    Male  experimental      No                 26.4
#
#     2024-04-06 00:00:00  2024-04-09 00:00:00    Mean bw  Group      Food  \
# 0                  19.9                 19.4  19.466667      1  2.333333
# 1                  21.7                 22.2  21.600000      1  2.966667
# 2                  20.0                 20.0  20.333333      1  2.766667
# 3                  19.7                 19.6  19.700000      1  3.433333
# 4                  20.3                 19.0  20.533333      1  2.066667
# 5                  22.0                 21.8  21.300000      1  2.833333
# 6                  20.5                 21.1  20.400000      2  2.700000
# 7                  19.9                 20.4  19.966667      2  2.833333
# 8                  20.6                 20.3  20.500000      2  2.733333
# 9                  19.9                 19.5  19.633333      2  2.900000
# 10                 21.5                 20.7  21.166667      2  2.933333
# 11                 21.4                 21.1  21.000000      2  3.100000
# 12                 20.6                 21.0  20.566667      3  2.766667
# 13                 21.0                 20.2  20.466667      3  2.433333
# 14                 19.8                 20.2  19.833333      3  2.800000
# 15                 19.3                 19.4  19.833333      3  2.633333
# 16                 20.6                 21.0  20.833333      3  3.000000
# 17                 22.6                 21.8  21.766667      3  3.000000
# 18                 21.2                 20.9  20.733333      4  2.633333
# 19                 20.4                 20.4  20.200000      4  2.633333
# 20                 20.5                 21.3  20.600000      4  3.033333
# 21                 21.9                 21.7  21.000000      4  3.000000
# 22                 19.0                 19.5  19.733333      4  2.800000
# 23                 21.9                 21.9  21.066667      4  3.133333
# 24                 26.3                 26.2  26.000000      5  3.333333
# 25                 26.8                 26.3  25.966667      5  3.033333
# 26                 25.0                 26.5  25.433333      5  3.566667
# 27                 26.4                 26.4  26.266667      5  3.333333
# 28                 23.1                 23.6  24.400000      5  3.300000
# 29                 26.7                 26.7  26.000000      5  3.266667
# 30                 25.1                 24.5  25.166667      6  2.600000
# 31                 25.3                 25.8  25.766667      6  3.200000
# 32                 25.9                 26.0  25.233333      6  3.366667
# 33                 25.7                 25.4  24.866667      6  2.833333
# 34                 26.5                 26.2  26.200000      6  2.900000
# 35                 27.8                 28.1  27.600000      6  3.733333
# 36                 22.8                 21.9  22.133333      7  2.566667
# 37                 24.7                 24.0  24.066667      7  2.900000
# 38                 26.4                 26.1  25.566667      7  3.133333
# 39                 26.8                 26.6  25.733333      7  3.366667
# 40                 27.6                 27.5  26.633333      7  3.600000
# 41                 26.0                 25.5  25.600000      7  3.000000
# 42                 25.0                 24.9  24.300000      8  3.133333
# 43                 24.8                 25.3  25.233333      8  3.433333
# 44                 24.6                 24.7  24.466667      8  3.433333
# 45                 25.0                 25.7  25.366667      8  3.033333
# 46                 24.7                 24.3  24.366667      8  3.133333
# 47                 26.8                 26.2  26.466667      8  3.366667
#
#     None None     None        None       None      None       None
# 0   None  NaN  Females        None       Mean        SD  Food mean
# 1   None  1.0  Control     Sucrose  20.488889  0.846868   2.733333
# 2   None  2.0       ND     Sucrose  20.444444  0.586768   2.866667
# 3   None  3.0  Control  No sucrose      20.55  0.720417   2.772222
# 4   None  4.0       ND  No sucrose  20.555556  0.508884   2.872222
# 5   None  NaN     None        None       None      None       None
# 6   None  NaN     None        None       None      None       None
# 7   None  NaN    Males        None       None      None       None
# 8   None  5.0  Control     Sucrose  25.677778  0.682696   3.305556
# 9   None  6.0       ND     Sucrose  25.805556  0.999426   3.105556
# 10  None  7.0  Control  No sucrose  24.955556  1.610199   3.094444
# 11  None  8.0       ND  No sucrose  25.033333  0.837722   3.255556
# 12  None  NaN     None        None       None      None       None
# 13  None  NaN     None        None       None      None       None
# 14  None  NaN     None        None       None      None       None
# 15  None  NaN     None        None       None      None       None
# 16  None  NaN     None        None       None      None       None
# 17  None  NaN     None        None       None      None       None
# 18  None  NaN     None        None       None      None       None
# 19  None  NaN     None        None       None      None       None
# 20  None  NaN     None        None       None      None       None
# 21  None  NaN     None        None       None      None       None
# 22  None  NaN     None        None       None      None       None
# 23  None  NaN     None        None       None      None       None
# 24  None  NaN     None        None       None      None       None
# 25  None  NaN     None        None       None      None       None
# 26  None  NaN     None        None       None      None       None
# 27  None  NaN     None        None       None      None       None
# 28  None  NaN     None        None       None      None       None
# 29  None  NaN     None        None       None      None       None
# 30  None  NaN     None        None       None      None       None
# 31  None  NaN     None        None       None      None       None
# 32  None  NaN     None        None       None      None       None
# 33  None  NaN     None        None       None      None       None
# 34  None  NaN     None        None       None      None       None
# 35  None  NaN     None        None       None      None       None
# 36  None  NaN     None        None       None      None       None
# 37  None  NaN     None        None       None      None       None
# 38  None  NaN     None        None       None      None       None
# 39  None  NaN     None        None       None      None       None
# 40  None  NaN     None        None       None      None       None
# 41  None  NaN     None        None       None      None       None
# 42  None  NaN     None        None       None      None       None
# 43  None  NaN     None        None       None      None       None
# 44  None  NaN     None        None       None      None       None
# 45  None  NaN     None        None       None      None       None
# 46  None  NaN     None        None       None      None       None
# 47  None  NaN     None        None       None      None       None

# %%
# Check if the "Group" column is categorical and convert it if necessary
df['Group'] = df['Group'].astype('category')

# Generate figure with one subplot
f, ax = plt.subplots(figsize=(12, 6))

# Plot today's data in the subplot
palette = ["red", "red", "red", "red", "red", "red", "red", "red"]

sns.stripplot(data=df, x="Group", y="Mean bw", hue="Group", palette=palette, ax=ax)
sns.pointplot(data=df, x='Group', y='Mean bw', capsize=.2, color="grey", markers='o', join=False, ax=ax)

# Set x-axis labels
group_labels = ["F Control + S", "F Exp + S", "F Control", "F Exp", "M Control + S", "M Exp + S", "M Control", "M Exp"]
ax.set_xticklabels(group_labels)
ax.set_xlabel("Groups")

# Set y-axis label
ax.set_ylabel("Mean bodyweight")

# Set legend title
ax.legend(title='Groups')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py in ?(vector, order)
#    1763                     order = vector.unique()
#    1764                 except AttributeError:
# -> 1765                     order = pd.unique(vector)
#    1766
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py in ?(vector, order)
#    1763                     order = vector.unique()
#    1764                 except AttributeError:
# -> 1765                     order = pd.unique(vector)
#    1766
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 11
#       8 palette = ["red", "red", "red", "red", "red", "red", "red", "red"]
#      10 sns.stripplot(data=df, x="Group", y="Mean bw", hue="Group", palette=palette, ax=ax)
# ---> 11 sns.pointplot(data=df, x='Group', y='Mean bw', capsize=.2, color="grey", markers='o', join=False, ax=ax)
#      13 # Set x-axis labels
#      14 group_labels = ["F Control + S", "F Exp + S", "F Control", "F Exp", "M Control + S", "M Exp + S", "M Control", "M Exp"]
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2839, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, ci, capsize, label, ax)
#    2829 def pointplot(
#    2830     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2831     estimator="mean", errorbar=("ci", 95), n_boot=1000, units=None, seed=None,
#    (...)
#    2834     capsize=None, label=None, ax=None,
#    2835 ):
#    2837     errorbar = utils._deprecate_ci(errorbar, ci)
# -> 2839     plotter = _PointPlotter(x, y, hue, data, order, hue_order,
#    2840                             estimator, errorbar, n_boot, units, seed,
#    2841                             markers, linestyles, dodge, join, scale,
#    2842                             orient, color, palette, errwidth, capsize, label)
#    2844     if ax is None:
#    2845         ax = plt.gca()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1601, in _PointPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, label)
#    1596 def __init__(self, x, y, hue, data, order, hue_order,
#    1597              estimator, errorbar, n_boot, units, seed,
#    1598              markers, linestyles, dodge, join, scale,
#    1599              orient, color, palette, errwidth, capsize, label):
#    1600     """Initialize the plotter."""
# -> 1601     self.establish_variables(x, y, hue, data, orient,
#    1602                              order, hue_order, units)
#    1603     self.establish_colors(color, palette, 1)
#    1604     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:605, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     601     hue_names = None
#     602 else:
#     603
#     604     # Get the order of the hue levels
# --> 605     hue_names = categorical_order(hue, hue_order)
#     607     # Group the hue data
#     608     plot_hues, hue_title = self._group_longform(hue, groups,
#     609                                                 group_names)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765, in categorical_order(vector, order)
#    1763     order = vector.unique()
#    1764 except AttributeError:
# -> 1765     order = pd.unique(vector)
#    1767 if variable_type(vector) == "numeric":
#    1768     order = np.sort(order)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:390, in unique(values)
#     296 def unique(values):
#     297     """
#     298     Return unique values based on a hash table.
#     299
#    (...)
#     388     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     389     """
# --> 390     return unique_with_mask(values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:418, in unique_with_mask(values, mask)
#     416 def unique_with_mask(values, mask: npt.NDArray[np.bool_] | None = None):
#     417     """See algorithms.unique for docs. Takes a mask for masked arrays."""
# --> 418     values = _ensure_arraylike(values)
#     420     if is_extension_array_dtype(values.dtype):
#     421         # Dispatch to extension dtype's unique.
#     422         return values.unique()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:227, in _ensure_arraylike(values)
#     225     if isinstance(values, tuple):
#     226         values = list(values)
# --> 227     values = construct_1d_object_array_from_listlike(values)
#     228 else:
#     229     values = np.asarray(values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1594, in construct_1d_object_array_from_listlike(values)
#    1591 # numpy will try to interpret nested lists as further dimensions, hence
#    1592 # making a 1D array that contains list-likes is a bit tricky:
#    1593 result = np.empty(len(values), dtype="object")
# -> 1594 result[:] = values
#    1595 return result
#
# ValueError: could not broadcast input array from shape (48,7) into shape (48,)
