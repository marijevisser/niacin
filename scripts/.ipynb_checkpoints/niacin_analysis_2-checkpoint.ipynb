# %% [markdown]
# Loading packages and data

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import trompy as tp
from scipy import stats

# %%
# read in data
PATH_TO_WORKBOOK = Path("../data/")
EXCEL_WORKBOOK = "measurements_b3_2.xlsx"
rows, header = tp.metafilereader(PATH_TO_WORKBOOK / EXCEL_WORKBOOK, sheetname="metafile_niacin_2")

# %% [markdown]
# grouping the animals and exploring the data frame

# %%
def get_value(row):
    if row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
        return 0
    elif row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'No':
        return 1
    elif row['sex'] == 'female' and row['diet'] == 'experimental' and row['sucrose'] == 'Yes':
        return 2
    elif row['sex'] == 'female' and row['diet'] == 'experimental' and row['sucrose'] == 'No':
        return 3
    elif row['sex'] == 'male' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
        return 4
    elif row['sex'] == 'male' and row['diet'] == 'control' and row['sucrose'] == 'No':
        return 5
    elif row['sex'] == 'male' and row['diet'] == 'experimental' and row['sucrose'] == 'Yes':
        return 6
    elif row['sex'] == 'male' and row['diet'] == 'experimental' and row['sucrose'] == 'No':
        return 7
    else:
        return -1

def tweak_df(df):
    
    return (df
            # .query("bodyweight != ''")
            .query("bodyweight.notna()", engine="python")
            .astype({"sex": "category",
                     "diet": "category",
                     "date": object, 
                     "bodyweight": float,
                     "food_yesterday": float,
                     "food_intake": float,
                     "sucrose_intake": float
                     }
                    )
             .assign(groupn = lambda df_: df_.apply(get_value, axis=1))
            )
    
df = tweak_df(pd.DataFrame(rows, columns=header))

# %%
df
# Out:
#     animal_id     sex          diet                 date sucrose  bodyweight  \
# 0       B3201  female       control  2024-04-06 00:00:00      No        20.6
# 1       B3202  female       control  2024-04-06 00:00:00      No        21.0
# 2       B3203  female  experimental  2024-04-06 00:00:00      No        21.2
# 3       B3204  female  experimental  2024-04-06 00:00:00      No        20.4
# 4       B3205  female       control  2024-04-06 00:00:00      No        19.8
# ..        ...     ...           ...                  ...     ...         ...
# 187     B3244    male  experimental  2024-04-15 00:00:00      No        25.0
# 188     B3245    male  experimental  2024-04-15 00:00:00      No        24.7
# 189     B3246    male  experimental  2024-04-15 00:00:00      No        26.6
# 190     B3247    male  experimental  2024-04-15 00:00:00     Yes        26.2
# 191     B3248    male  experimental  2024-04-15 00:00:00     Yes        28.6
#
#      food_yesterday  food_today  food_intake  sucrose_yesterday  \
# 0              -1.0        80.8    -1.000000               -1.0
# 1              -1.0        98.6    -1.000000               -1.0
# 2              -1.0       139.3    -1.000000               -1.0
# 3              -1.0       139.3    -1.000000               -1.0
# 4              -1.0        80.2    -1.000000               -1.0
# ..              ...         ...          ...                ...
# 187            71.7        63.4     2.766667               -1.0
# 188            46.5        37.3     3.066667               -1.0
# 189            69.8        60.2     3.200000               -1.0
# 190            65.1        61.3     1.266667               55.2
# 191            56.3        51.7     1.533333               54.9
#
#      sucrose_today  sucrose_intake  groupn
# 0             -1.0       -1.000000       1
# 1             -1.0       -1.000000       1
# 2             -1.0       -1.000000       3
# 3             -1.0       -1.000000       3
# 4             -1.0       -1.000000       1
# ..             ...             ...     ...
# 187           -1.0       -1.000000       7
# 188           -1.0       -1.000000       7
# 189           -1.0       -1.000000       7
# 190           37.2        6.000000       6
# 191           36.5        6.133333       6
#
# [192 rows x 13 columns]

# %%
df.dtypes
# Out:
# animal_id              object
# sex                  category
# diet                 category
# date                   object
# sucrose                object
# bodyweight            float64
# food_yesterday        float64
# food_today            float64
# food_intake           float64
# sucrose_yesterday     float64
# sucrose_today         float64
# sucrose_intake        float64
# groupn                  int64
# dtype: object

# %%
df.columns
# Out:
# Index(['animal_id', 'sex', 'diet', 'date', 'sucrose', 'bodyweight',
#        'food_yesterday', 'food_today', 'food_intake', 'sucrose_yesterday',
#        'sucrose_today', 'sucrose_intake', 'groupn'],
#       dtype='object')

# %%
df.animal_id.unique()
df.date.unique()
# Out:
# array([Timestamp('2024-04-06 00:00:00'), Timestamp('2024-04-09 00:00:00'),
#        Timestamp('2024-04-12 00:00:00'), Timestamp('2024-04-15 00:00:00')],
#       dtype=object)

# %%
df.groupby(["sex", "diet", "date"]).mean(numeric_only=True).reset_index()
# Out:
#        sex          diet       date  bodyweight  food_yesterday  food_today  \
# 0   female       control 2024-04-06   20.625000       -1.000000   79.458333
# 1   female       control 2024-04-09   20.466667       79.458333   69.700000
# 2   female       control 2024-04-12   20.858333       69.700000   59.250000
# 3   female       control 2024-04-15   21.158333       59.250000   50.641667
# 4   female  experimental 2024-04-06   20.725000       -1.000000   87.141667
# 5   female  experimental 2024-04-09   20.733333       87.141667   77.216667
# 6   female  experimental 2024-04-12   21.483333       77.216667   66.316667
# 7   female  experimental 2024-04-15   21.925000       66.316667   57.983333
# 8     male       control 2024-04-06   25.716667       -1.000000   63.650000
# 9     male       control 2024-04-09   25.608333       63.650000   54.050000
# 10    male       control 2024-04-12   26.075000       54.050000   44.716667
# 11    male       control 2024-04-15   26.200000       47.100000   40.700000
# 12    male  experimental 2024-04-06   25.600000       -1.000000   80.091667
# 13    male  experimental 2024-04-09   25.591667       80.091667   70.550000
# 14    male  experimental 2024-04-12   25.666667       70.550000   61.433333
# 15    male  experimental 2024-04-15   25.908333       61.433333   54.808333
#
#     food_intake  sucrose_yesterday  sucrose_today  sucrose_intake  groupn
# 0     -1.000000          -1.000000      -1.000000       -1.000000     1.0
# 1      2.752778          -1.000000      -1.000000       -1.000000     1.0
# 2      2.969444          -1.000000      26.783333       -1.000000     0.5
# 3      2.347222          26.783333      19.233333        2.016667     0.5
# 4     -1.000000          -1.000000      -1.000000       -1.000000     3.0
# 5      2.869444          -1.000000      -1.000000       -1.000000     3.0
# 6      3.158333          -1.000000      26.850000       -1.000000     2.5
# 7      2.300000          26.850000      17.675000        2.558333     2.5
# 8     -1.000000          -1.000000      -1.000000       -1.000000     5.0
# 9      3.200000          -1.000000      -1.000000       -1.000000     5.0
# 10     3.111111          -1.000000      26.858333       -1.000000     4.5
# 11     2.133333          26.858333      17.000000        2.786111     4.5
# 12    -1.000000          -1.000000      -1.000000       -1.000000     7.0
# 13     3.180556          -1.000000      -1.000000       -1.000000     7.0
# 14     3.038889          -1.000000      26.975000       -1.000000     6.5
# 15     2.208333          26.975000      17.600000        2.625000     6.5

# %%
# remove outliers
# is done by creating the new dataframe df_food_water
# Clean up df


def replace_outliers(df, column):
    
    values=[]
    for idx, row in df.iterrows():
        if row[column] < 1:
            values.append(np.nan)
        elif row[column] > np.mean(df[column]) * 2:
            values.append(np.nan)
        else:
            values.append(row[column])
    
    print("the number of outliers being replaced for", column, "is", np.sum(np.isnan(values)))
    df[column] = values
    mean_by_animal = df.groupby(["animal_id"]).mean(numeric_only=True).reset_index()
            
    values=[]
    for idx, row in df.iterrows():
        if np.isnan(row[column]):
            values.append(mean_by_animal.query('animal_id == @row.animal_id')[column].values[0])
        else:
            values.append(row[column])
    
    return values
    
def remove_and_clean(df):
    """Removes unecessary rows and cleans data to get rid of erroneous values.

    Args:
        df (Pandas dataframe): Contains data from niacin experiment

    Returns:
        Dataframe: Cleaned dataframe
    """
    return (df
            .query("food_yesterday != -1.0")
            
            .assign(food_intake = lambda df_: replace_outliers(df_, "food_intake"))
            .assign(sucrose_intake = lambda df_: replace_outliers(df_, "sucrose_intake"))
    )

df_food_water = remove_and_clean(df)
# Out:
# the number of outliers being replaced for food_intake is 1
# the number of outliers being replaced for sucrose_intake is 144

# %%
# Find mean and SEM of all data - food intake
mean_fw = df_food_water.groupby(["sex", "diet", "sucrose", "date"]).mean(numeric_only=True).reset_index()
sem_fw = df_food_water.groupby(["sex", "diet", "sucrose","date"]).sem(numeric_only=True).reset_index()

# Generate figure with two subplots
f, ax = plt.subplots(ncols=2, figsize=(12, 6), sharey=True,
                     gridspec_kw={"width_ratios": [3, 1]},)

# Set x values
x = np.arange(len(mean_fw.query("sex == 'female' and sucrose == 'Yes' and diet == 'experimental'")))

# Plot data for each group in first subplot
ax[0].errorbar(x,
               mean_fw.query("sex == 'female' and sucrose == 'Yes' and diet == 'experimental'").food_intake,
               yerr=sem_fw.query("sex == 'female' and sucrose =='Yes' and diet == 'control'").food_intake,
               marker="s", markerfacecolor="hotpink", color="hotpink",
               label="Experimental + sucrose"
              )

x = np.arange(len(mean_fw.query("sex == 'female' and sucrose == 'Yes' and diet == 'control'")))

ax[0].errorbar(x,
               mean_fw.query("sex == 'female' and sucrose == 'Yes' and diet == 'control'").food_intake,
               yerr=sem_fw.query("sex == 'male' and sucrose =='Yes' and diet == 'control'").food_intake,
               marker="s", markerfacecolor="green", color="green",
               label="Control + sucrose"
              )

x = np.arange(len(mean_fw.query("sex == 'female' and sucrose == 'No' and diet == 'experimental'")))

ax[0].errorbar(x,
               mean_fw.query("sex == 'female' and sucrose == 'No' and diet == 'experimental'").food_intake,
               yerr=sem_fw.query("sex == 'female' and sucrose == 'No' and diet == 'experimental'").food_intake,
               marker="o", markerfacecolor="white", color="hotpink",
               label="Experimental + no sucrose"
              )

x = np.arange(len(mean_fw.query("sex == 'female' and sucrose == 'No' and diet == 'control'")))

ax[0].errorbar(x,
               mean_fw.query("sex == 'female' and sucrose == 'No' and diet == 'control'").food_intake,
               yerr=sem_fw.query("sex == 'female' and sucrose == 'No' and diet == 'control'").food_intake,
               marker="o", markerfacecolor="white", color="green",
               label="Control + no sucrose"
              )
 

# Set x axis limits and ticks
ax[0].set_xlim([0, 7])
ax[0].set_xticks(np.arange(0, 7, 1)) 
ax[0].set_ylim([0, 4.5])

# Add labels
ax[0].set_ylabel("Food intake (g)")
ax[0].set_xlabel("Days")
ax[0].legend()

# Plot today's data in second subplot
today = df_food_water.date.max()
today_df = df_food_water.query("date == @today")
today_df_females = today_df[today_df['groupn'].isin(['E-S', 'C-S', 'E-NS', 'C-NS'])]

palette = ["hotpink", "green", "hotpink", "green"]

# Use 'hue' to match the lengths of the arrays
sns.stripplot(data=today_df_females, x="groupn", y="food_intake", hue="groupn", palette=palette, ax=ax[1])
sns.pointplot(data=today_df_females, x='groupn', y='food_intake', hue='groupn', capsize=.2, color="grey", markers='o', join=False, ax=ax[1])

ax[1].set_xticklabels(["E-S", "C-S", "E-NS", "C-NS"])
ax[1].set_xlabel("")
ax[1].set_ylabel("Food intake (g)")
ax[1].legend().remove()
# Out:
# C:\Users\marije\AppData\Local\Temp\ipykernel_17712\2790593351.py:66: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(data=today_df_females, x="groupn", y="food_intake", hue="groupn", palette=palette, ax=ax[1])
# C:\Users\marije\AppData\Local\Temp\ipykernel_17712\2790593351.py:66: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.stripplot(data=today_df_females, x="groupn", y="food_intake", hue="groupn", palette=palette, ax=ax[1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 67
#      65 # Use 'hue' to match the lengths of the arrays
#      66 sns.stripplot(data=today_df_females, x="groupn", y="food_intake", hue="groupn", palette=palette, ax=ax[1])
# ---> 67 sns.pointplot(data=today_df_females, x='groupn', y='food_intake', hue='groupn', capsize=.2, color="grey", markers='o', join=False, ax=ax[1])
#      69 ax[1].set_xticklabels(["E-S", "C-S", "E-NS", "C-NS"])
#      70 ax[1].set_xlabel("")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2839, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, ci, capsize, label, ax)
#    2829 def pointplot(
#    2830     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2831     estimator="mean", errorbar=("ci", 95), n_boot=1000, units=None, seed=None,
#    (...)
#    2834     capsize=None, label=None, ax=None,
#    2835 ):
#    2837     errorbar = utils._deprecate_ci(errorbar, ci)
# -> 2839     plotter = _PointPlotter(x, y, hue, data, order, hue_order,
#    2840                             estimator, errorbar, n_boot, units, seed,
#    2841                             markers, linestyles, dodge, join, scale,
#    2842                             orient, color, palette, errwidth, capsize, label)
#    2844     if ax is None:
#    2845         ax = plt.gca()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1603, in _PointPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, label)
#    1600 """Initialize the plotter."""
#    1601 self.establish_variables(x, y, hue, data, orient,
#    1602                          order, hue_order, units)
# -> 1603 self.establish_colors(color, palette, 1)
#    1604 self.estimate_statistic(estimator, errorbar, n_boot, seed)
#    1606 # Override the default palette for single-color plots
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:707, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     705 # Determine the gray color to use for the lines framing the plot
#     706 light_vals = [rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 707 lum = min(light_vals) * .6
#     708 gray = mpl.colors.rgb2hex((lum, lum, lum))
#     710 # Assign object attributes
#
# ValueError: min() arg is an empty sequence
