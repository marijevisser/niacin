# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import trompy as tp
from scipy import stats

# %%
# read in data
PATH_TO_WORKBOOK = Path("../data/")
EXCEL_WORKBOOK = "measurements_b3_1.xlsx"
rows, header = tp.metafilereader(PATH_TO_WORKBOOK / EXCEL_WORKBOOK, sheetname="metafile_niacin")


# how about a google drive but that we save a csv file for every day

# %% [markdown]
# Showing the data set (such as columns) and creating a new variable for the four groups

# %%
# Clean up df

def replace_outliers(df, column):
    
    values=[]
    for idx, row in df.iterrows():
        if row[column] < 1:
            values.append(np.nan)
        elif row[column] > np.mean(df[column]) * 2:
            values.append(np.nan)
        else:
            values.append(row[column])
    
    print("the number of outliers being replaced for", column, "is", np.sum(np.isnan(values)))
    df[column] = values
    mean_by_animal = df.groupby(["animal_id"]).mean(numeric_only=True).reset_index()
            
    values=[]
    for idx, row in df.iterrows():
        if np.isnan(row[column]):
            values.append(mean_by_animal.query('animal_id == @row.animal_id')[column].values[0])
        else:
            values.append(row[column])
    
    return values
    
def remove_and_clean(df):
    """Removes unecessary rows and cleans data to get rid of erroneous values.

    Args:
        df (Pandas dataframe): Contains data from niacin experiment

    Returns:
        Dataframe: Cleaned dataframe
    """
    return (df
            .query("food_yesterday != -1.0")
            
            .assign(food_intake = lambda df_: replace_outliers(df_, "food_intake"))
            .assign(water_intake = lambda df_: replace_outliers(df_, "water_intake"))
    )

df_food_water = remove_and_clean(df)
# Out:
# the number of outliers being replaced for food_intake is 7
# the number of outliers being replaced for water_intake is 5

# %%
def get_value(row):
    if row['sex'] == 'female' and row['group'] == 'control':
        return 0
    elif row['sex'] == 'female' and row['group'] == 'experimental':
        return 1
    elif row['sex'] == 'male' and row['group'] == 'control':
        return 2
    elif row['sex'] == 'male' and row['group'] == 'experimental':
        return 3
    else:
        return -1

def tweak_df(df):
    
    return (df
            # .query("bodyweight != ''")
            .query("bodyweight.notna()", engine="python")
            .astype({"sex": "category",
                     "group": "category",
                     "diet": "category",
                     "bodyweight": float,
                     "food_yesterday": float,
                     "food_intake": float,
                     "water_intake": float
                     }
                    )
             .assign(groupn = lambda df_: df_.apply(get_value, axis=1))
            )
    
df = tweak_df(pd.DataFrame(rows, columns=header))

# %%
df
# Out:
#      animal_id     sex         group          diet        date  niacin  \
# 0        B3101    male       control       control  2024-02-12     0.0
# 1        B3102    male       control       control  2024-02-12     0.0
# 2        B3103    male  experimental       control  2024-02-12     0.0
# 3        B3104    male  experimental       control  2024-02-12     0.0
# 4        B3105    male       control       control  2024-02-12     0.0
# ...        ...     ...           ...           ...         ...     ...
# 1179     B3128  female  experimental  experimental  2024-03-25     0.0
# 1180     B3129  female       control       control  2024-03-25     0.0
# 1181     B3130  female       control       control  2024-03-25     0.0
# 1182     B3131  female  experimental  experimental  2024-03-25     0.0
# 1183     B3132  female  experimental  experimental  2024-03-25     0.0
#
#       bodyweight  food_yesterday food_today  food_intake  water_yesterday  \
# 0           21.8            -1.0       60.7    -1.000000             -1.0
# 1           24.7            -1.0         56    -1.000000             -1.0
# 2           24.9            -1.0       54.5    -1.000000             -1.0
# 3           24.9            -1.0       54.5    -1.000000             -1.0
# 4           25.4            -1.0       56.3    -1.000000             -1.0
# ...          ...             ...        ...          ...              ...
# 1179        22.5            53.5       43.6     3.300000             51.4
# 1180        22.2            37.8       28.9     2.966667             51.4
# 1181        24.0            54.5       44.1     3.466667             51.3
# 1182        22.2            66.7         57     3.233333             52.0
# 1183        22.3            54.5       44.5     3.333333             51.7
#
#      water_today  water_intake  groupn
# 0           50.9     -1.000000       2
# 1           50.4     -1.000000       2
# 2           50.5     -1.000000       3
# 3           50.5     -1.000000       3
# 4           50.9     -1.000000       2
# ...          ...           ...     ...
# 1179        38.9      4.166667       1
# 1180        42.5      2.966667       0
# 1181        42.5      2.933333       0
# 1182        43.9      2.700000       1
# 1183        40.8      3.633333       1
#
# [1184 rows x 14 columns]

# %%
df.dtypes
# Out:
# animal_id            object
# sex                category
# group              category
# diet               category
# date                 object
# niacin              float64
# bodyweight          float64
# food_yesterday      float64
# food_today           object
# food_intake         float64
# water_yesterday     float64
# water_today          object
# water_intake        float64
# groupn                int64
# dtype: object

# %%
df.columns
# Out:
# Index(['animal_id', 'sex', 'group', 'diet', 'date', 'niacin', 'bodyweight',
#        'food_yesterday', 'food_today', 'food_intake', 'water_yesterday',
#        'water_today', 'water_intake', 'groupn'],
#       dtype='object')

# %%
df.animal_id.unique()
df.date.unique()
# Out:
# array(['2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#        '2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23',
#        '2024-02-24', '2024-02-25', '2024-02-26', '2024-02-27',
#        '2024-02-28', '2024-02-29', '2024-03-01', '2024-03-02',
#        '2024-03-03', '2024-03-04', '2024-03-05', '2024-03-06',
#        '2024-03-07', '2024-03-08', '2024-03-09', '2024-03-10',
#        '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14',
#        '2024-03-15', '2024-03-18', '2024-03-20', '2024-03-22',
#        '2024-03-25'], dtype=object)

# %%
df.groupby(["sex", "group", "date"]).mean(numeric_only=True).reset_index()
# Out:
#         sex         group        date  niacin  bodyweight  food_yesterday  \
# 0    female       control  2024-02-12     0.0     20.4125         -1.0000
# 1    female       control  2024-02-13     0.0     19.9375         77.4500
# 2    female       control  2024-02-14     0.0     20.0625         74.5625
# 3    female       control  2024-02-15     0.0     20.0875         71.6250
# 4    female       control  2024-02-16     0.0     20.2125         72.7875
# ..      ...           ...         ...     ...         ...             ...
# 143    male  experimental  2024-03-15     0.0     28.1250         51.7250
# 144    male  experimental  2024-03-18     1.5     28.0375         48.7000
# 145    male  experimental  2024-03-20     1.5     28.3625         44.6000
# 146    male  experimental  2024-03-22     1.5     28.7875         48.1625
# 147    male  experimental  2024-03-25     1.5     28.7250         60.3750
#
#      food_intake  water_yesterday  water_intake  groupn
# 0      -1.000000          -1.0000     -1.000000     0.0
# 1       2.887500          51.5000      9.012500     0.0
# 2       2.937500          51.2875      3.062500     0.0
# 3       2.987500          51.5250      3.000000     0.0
# 4       3.362500          51.7500      3.150000     0.0
# ..           ...              ...           ...     ...
# 143     3.025000          48.5750      2.475000     3.0
# 144     2.854167          50.7125      2.279167     3.0
# 145     2.881250          51.3500      2.381250     3.0
# 146     3.018750          46.5875      2.418750     3.0
# 147     2.791667          51.7500      2.350000     3.0
#
# [148 rows x 10 columns]

# %% [markdown]
# Performing t tests on the data
#  (normality and equality of variances check hasn't been performed yet)
# But first removing outliers from the dataset

# %%
#t tests for females - bodyweight
female_experimental_data = df_food_water[(df_food_water['sex'] == 'female') & (df_food_water['group'] == 'experimental')]
female_control_data = df_food_water[(df_food_water["sex"] == "female") & (df_food_water["group"] == "control")]

for day in df_food_water["date"].unique():  # Iterate over unique dates
    control_data = female_control_data[female_control_data['date'] == day]['bodyweight']
    experimental_data = female_experimental_data[female_experimental_data['date'] == day]['bodyweight']
    
    t_statistic, p_value = stats.ttest_ind(control_data, experimental_data)
    
    # Print results for each day
    print("Day:", day)
    print("t-statistic:", t_statistic)
    print("p-value:", p_value)
    
    # Interpret the results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis - There is a significant difference in body weight between the groups at this time point.")
    else:
        print("Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.")
    print()
# Out:
# Day: 2024-02-13
# t-statistic: -1.2082752965060406
# p-value: 0.2469554602734486
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-14
# t-statistic: -0.8882038106453871
# p-value: 0.38943654021832985
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-15
# t-statistic: -1.502752910229976
# p-value: 0.15512108630446475
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-16
# t-statistic: -0.7177627307884807
# p-value: 0.4847092040082437
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-17
# t-statistic: -0.7409486090900833
# p-value: 0.4709706824307748
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-18
# t-statistic: -0.6456509690942387
# p-value: 0.528946365823742
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-19
# t-statistic: -1.048414781333712
# p-value: 0.3122105408368594
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-20
# t-statistic: -0.9760528637131775
# p-value: 0.3456032074609485
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-21
# t-statistic: -0.23812952476972238
# p-value: 0.8152306285185316
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-22
# t-statistic: -0.13390846181153215
# p-value: 0.895380880906449
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-23
# t-statistic: 0.09775640129001445
# p-value: 0.9235115071610389
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-24
# t-statistic: -1.0445351492086767
# p-value: 0.3139390438901301
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-25
# t-statistic: -0.8714860980247746
# p-value: 0.3981876710856579
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-26
# t-statistic: 1.0182200587904623e-14
# p-value: 0.999999999999992
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-27
# t-statistic: -0.7224078311821458
# p-value: 0.48193761814876923
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-28
# t-statistic: -0.55250912634219
# p-value: 0.5893125962865209
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-29
# t-statistic: 0.8043527285578044
# p-value: 0.434640155417542
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-01
# t-statistic: 0.08030343192653328
# p-value: 0.937132577607706
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-02
# t-statistic: 0.10664846086433202
# p-value: 0.9165810333550597
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-03
# t-statistic: 0.1374532186397993
# p-value: 0.8926298382974752
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-04
# t-statistic: 0.2842758261344172
# p-value: 0.7803603345661688
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-05
# t-statistic: 0.028419381481634736
# p-value: 0.9777288138494282
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-06
# t-statistic: 0.40239200674031905
# p-value: 0.6934722565376079
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-07
# t-statistic: 0.24886415921804922
# p-value: 0.8070796220833082
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-08
# t-statistic: 0.978934929120621
# p-value: 0.344226474595997
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-09
# t-statistic: 0.599239543420652
# p-value: 0.5585863856463629
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-10
# t-statistic: 0.12796198265831177
# p-value: 0.8999989915734092
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-11
# t-statistic: -0.03104495237358527
# p-value: 0.97567193217056
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-12
# t-statistic: -0.027436638186156933
# p-value: 0.9784987415885482
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-13
# t-statistic: 8.383187909769306e-15
# p-value: 0.9999999999999934
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-14
# t-statistic: -0.16379299911269737
# p-value: 0.8722351843854634
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-15
# t-statistic: -0.482153839270458
# p-value: 0.6371475121701804
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-18
# t-statistic: 0.1352198239684752
# p-value: 0.8943629838895137
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-20
# t-statistic: 0.24575779514398477
# p-value: 0.809435997875071
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-22
# t-statistic: -0.49183212596285886
# p-value: 0.630459869048016
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-25
# t-statistic: 0.7179974857416562
# p-value: 0.484568903374479
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.

# %%
#t tests for females - food intake
female_experimental_data = df_food_water[(df_food_water['sex'] == 'female') & (df_food_water['group'] == 'experimental')]
female_control_data = df_food_water[(df_food_water["sex"] == "female") & (df_food_water["group"] == "control")]

for day in df_food_water["date"].unique():  # Iterate over unique dates
    control_data = female_control_data[female_control_data['date'] == day]['food_intake']
    experimental_data = female_experimental_data[female_experimental_data['date'] == day]['food_intake']
    
    t_statistic, p_value = stats.ttest_ind(control_data, experimental_data)
    
    # Print results for each day
    print("Day:", day)
    print("t-statistic:", t_statistic)
    print("p-value:", p_value)
    
    # Interpret the results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis - There is a significant difference in food intake between the groups at this time point.")
    else:
        print("Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.")
    print()
# Out:
# Day: 2024-02-13
# t-statistic: 0.18968247235793748
# p-value: 0.8522805928992132
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-14
# t-statistic: -0.5417023090757583
# p-value: 0.5965399873321169
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-15
# t-statistic: 0.05397245024022033
# p-value: 0.9577197408319085
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-16
# t-statistic: -0.11675588928432197
# p-value: 0.9087118725947871
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-17
# t-statistic: 0.7867957924694411
# p-value: 0.4445168643786436
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-18
# t-statistic: 0.6172133998483708
# p-value: 0.5470018820750974
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-19
# t-statistic: 0.4125812950947172
# p-value: 0.686162057999619
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-20
# t-statistic: -0.05917559357909155
# p-value: 0.9536486381039815
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-21
# t-statistic: -0.19301829317986716
# p-value: 0.8497167805737401
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-22
# t-statistic: 1.171813697176
# p-value: 0.2608284229772793
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-23
# t-statistic: -0.1669983419532613
# p-value: 0.8697594312299318
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-24
# t-statistic: 0.7747796376317183
# p-value: 0.45135790790460106
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-25
# t-statistic: 1.4117731575135668
# p-value: 0.1798554454601227
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-26
# t-statistic: -0.6222813210704554
# p-value: 0.5437595013820293
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-27
# t-statistic: -0.26022035123543663
# p-value: 0.7984819226208066
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-28
# t-statistic: 0.4735232034697158
# p-value: 0.643139059471233
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-29
# t-statistic: 1.1597431913379854
# p-value: 0.2655506622584762
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-01
# t-statistic: 0.6069769786668906
# p-value: 0.5535832579206361
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-02
# t-statistic: 0.9047738677647265
# p-value: 0.3808917799122248
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-03
# t-statistic: 0.2740244371100979
# p-value: 0.7880674648014723
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-04
# t-statistic: 1.9110661718118163
# p-value: 0.07668988567666202
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-05
# t-statistic: 0.7016464154456263
# p-value: 0.4943993136528456
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-06
# t-statistic: 0.058707563740742076
# p-value: 0.9540147861465724
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-07
# t-statistic: 0.672455487321616
# p-value: 0.5122403252247316
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-08
# t-statistic: 1.0972267870413206
# p-value: 0.2910565202990814
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-09
# t-statistic: 0.44411686861058514
# p-value: 0.6637456597446754
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-10
# t-statistic: -0.40347329239297336
# p-value: 0.6926949791400513
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-11
# t-statistic: 0.06658217149117931
# p-value: 0.9478558431845994
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-12
# t-statistic: 1.2862913567872016
# p-value: 0.21920725005485656
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-13
# t-statistic: 0.5404136712877797
# p-value: 0.5974047867957075
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-14
# t-statistic: -0.5531825457855206
# p-value: 0.5888637135331839
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-15
# t-statistic: -0.34628650983698556
# p-value: 0.734276591680789
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-18
# t-statistic: 1.2386972781201653
# p-value: 0.23582509611016989
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-20
# t-statistic: 0.675434536152318
# p-value: 0.5104026307960272
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-22
# t-statistic: -0.4527265912326284
# p-value: 0.6576820822121505
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-25
# t-statistic: 1.5303383560085453
# p-value: 0.14821137066261658
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.

# %%
#t tests for females - water intake
female_experimental_data = df_food_water[(df_food_water['sex'] == 'female') & (df_food_water['group'] == 'experimental')]
female_control_data = df_food_water[(df_food_water["sex"] == "female") & (df_food_water["group"] == "control")]

for day in df_food_water["date"].unique():  # Iterate over unique dates
    control_data = female_control_data[female_control_data['date'] == day]['water_intake']
    experimental_data = female_experimental_data[female_experimental_data['date'] == day]['water_intake']
    
    t_statistic, p_value = stats.ttest_ind(control_data, experimental_data)
    
    # Print results for each day
    print("Day:", day)
    print("t-statistic:", t_statistic)
    print("p-value:", p_value)
    
    # Interpret the results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis - There is a significant difference in water intake between the groups at this time point.")
    else:
        print("Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.")
    print()
# Out:
# Day: 2024-02-13
# t-statistic: 0.6939076658142835
# p-value: 0.4990929300529223
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-14
# t-statistic: 1.5939701191492737
# p-value: 0.13326281504951323
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-15
# t-statistic: -0.25819888974716076
# p-value: 0.8000104103653621
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-16
# t-statistic: -0.2778347225812983
# p-value: 0.7852001015366507
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-17
# t-statistic: 0.9701425001453265
# p-value: 0.34843869825643436
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-18
# t-statistic: 0.7145896010105026
# p-value: 0.48660801178120194
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-19
# t-statistic: -0.9047738677647695
# p-value: 0.3808917799122028
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-20
# t-statistic: 0.2723457094034351
# p-value: 0.7893317772499849
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-21
# t-statistic: 0.6585046078685082
# p-value: 0.5208970102533916
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-22
# t-statistic: 1.6193489499400298
# p-value: 0.12767180218588176
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-23
# t-statistic: -0.8212463518149116
# p-value: 0.42527045866471413
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-24
# t-statistic: -0.5753161456523076
# p-value: 0.5742084247318937
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-25
# t-statistic: 1.02888680553696
# p-value: 0.32098177002911416
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-26
# t-statistic: 5.163724019248328
# p-value: 0.00014382798410657367
# Reject the null hypothesis - There is a significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-27
# t-statistic: -0.7901103760440294
# p-value: 0.4426414129472337
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-28
# t-statistic: -6.875964492165915e-15
# p-value: 0.9999999999999947
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-29
# t-statistic: 1.4834917133409937
# p-value: 0.1601050152394943
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-01
# t-statistic: 3.489113503954595
# p-value: 0.0036125306486048353
# Reject the null hypothesis - There is a significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-02
# t-statistic: 0.519122096001311
# p-value: 0.6117842592297558
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-03
# t-statistic: 2.0465496942340526
# p-value: 0.05995808825642727
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-04
# t-statistic: 1.33008854884234
# p-value: 0.20475210123972748
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-05
# t-statistic: 0.5139561687500395
# p-value: 0.6152986283386537
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-06
# t-statistic: -0.5435354301834089
# p-value: 0.5953108788051489
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-07
# t-statistic: -1.2234173100260681
# p-value: 0.24136539277474905
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-08
# t-statistic: -0.15497838448275048
# p-value: 0.8790505348800464
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-09
# t-statistic: 0.3855176431903005
# p-value: 0.7056482503018258
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-10
# t-statistic: 0.5983063057309644
# p-value: 0.5591914746489872
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-11
# t-statistic: 0.46776427696374895
# p-value: 0.6471514286645904
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-12
# t-statistic: -1.2517537366505305
# p-value: 0.23117053996119194
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-13
# t-statistic: -0.2608963396425815
# p-value: 0.7979709784063621
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-14
# t-statistic: -1.5183586879960478
# p-value: 0.15117942980175575
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-15
# t-statistic: 0.14828673433958958
# p-value: 0.8842311193811039
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-18
# t-statistic: -0.9342783812686128
# p-value: 0.3659956946457278
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-20
# t-statistic: -0.3996509886024705
# p-value: 0.6954442288121134
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-22
# t-statistic: -1.5050124784047425
# p-value: 0.1545450630931956
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-25
# t-statistic: -0.9612225609608739
# p-value: 0.3527490266301444
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.

# %%
#t tests for males - body weight
male_experimental_data = df_food_water[(df_food_water['sex'] == 'male') & (df_food_water['group'] == 'experimental')]
male_control_data = df_food_water[(df_food_water["sex"] == "male") & (df_food_water["group"] == "control")]

for day in df_food_water["date"].unique():  # Iterate over unique dates
    control_data = male_control_data[male_control_data['date'] == day]['bodyweight']
    experimental_data = male_experimental_data[male_experimental_data['date'] == day]['bodyweight']
    
    t_statistic, p_value = stats.ttest_ind(control_data, experimental_data)
    
    # Print results for each day
    print("Day:", day)
    print("t-statistic:", t_statistic)
    print("p-value:", p_value)
    
    # Interpret the results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis - There is a significant difference in body weight between the groups at this time point.")
    else:
        print("Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.")
    print()
# Out:
# Day: 2024-02-13
# t-statistic: -0.11009065766597023
# p-value: 0.9139000405415773
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-14
# t-statistic: -0.9137080416200226
# p-value: 0.3763380423523791
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-15
# t-statistic: -1.1349008767288875
# p-value: 0.2754746122452408
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-16
# t-statistic: -1.447830410173213
# p-value: 0.16968693424714965
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-17
# t-statistic: -1.1090412261584421
# p-value: 0.2861006693401651
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-18
# t-statistic: -0.568309350522027
# p-value: 0.5788270516294851
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-19
# t-statistic: -0.9276248190287084
# p-value: 0.36931924978558117
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-20
# t-statistic: -1.0436336277572686
# p-value: 0.31434169988989014
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-21
# t-statistic: -0.931199003316075
# p-value: 0.36753130854684257
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-22
# t-statistic: -0.6860731812353521
# p-value: 0.5038712773590912
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-23
# t-statistic: -1.214606445398802
# p-value: 0.24460601729022743
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-24
# t-statistic: -0.984112577346663
# p-value: 0.3417629353178444
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-25
# t-statistic: -0.6098367211363063
# p-value: 0.551740294622922
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-26
# t-statistic: -0.18194160461247066
# p-value: 0.8582366248021095
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-27
# t-statistic: -0.9764476593848755
# p-value: 0.3454143877004403
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-28
# t-statistic: -1.1318900964423975
# p-value: 0.2766962102143487
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-02-29
# t-statistic: -1.4965468499958146
# p-value: 0.15671248413761635
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-01
# t-statistic: -1.3416407864998698
# p-value: 0.20107012031483645
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-02
# t-statistic: -1.170755660021081
# p-value: 0.2612397566591681
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-03
# t-statistic: -0.8673564632237001
# p-value: 0.4003695061728495
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-04
# t-statistic: -0.33283612618925534
# p-value: 0.7441896353443755
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-05
# t-statistic: -1.063577236101576
# p-value: 0.3055219663807594
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-06
# t-statistic: -0.8271842694681497
# p-value: 0.4220084229735661
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-07
# t-statistic: -1.0807771676282991
# p-value: 0.298062995969291
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-08
# t-statistic: -0.07677266418184794
# p-value: 0.9398907759875015
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-09
# t-statistic: -0.5929297958002929
# p-value: 0.5626843416257473
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-10
# t-statistic: -0.5105543172412151
# p-value: 0.6176182704935986
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-11
# t-statistic: -0.6438845164875532
# p-value: 0.530058045890063
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-12
# t-statistic: -0.8446938245125408
# p-value: 0.4124845662423908
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-13
# t-statistic: -0.5526599397501643
# p-value: 0.589212053018823
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-14
# t-statistic: -0.1136447497744259
# p-value: 0.9111330381926375
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-15
# t-statistic: -0.12036124373775033
# p-value: 0.9059072756909206
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-18
# t-statistic: -0.05394579821583671
# p-value: 0.95774059746623
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-20
# t-statistic: -0.013938333839872065
# p-value: 0.9890758626107281
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-22
# t-statistic: -0.07318161615984674
# p-value: 0.9426968859306177
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.
#
# Day: 2024-03-25
# t-statistic: -0.297302536944338
# p-value: 0.7706012470840038
# Fail to reject the null hypothesis - There is no significant difference in body weight between the groups at this time point.

# %%
#t tests for males - water intake
male_experimental_data = df_food_water[(df_food_water['sex'] == 'male') & (df_food_water['group'] == 'experimental')]
male_control_data = df_food_water[(df_food_water["sex"] == "male") & (df_food_water["group"] == "control")]

for day in df_food_water["date"].unique():  # Iterate over unique dates
    control_data = male_control_data[male_control_data['date'] == day]['water_intake']
    experimental_data = male_experimental_data[male_experimental_data['date'] == day]['water_intake']
    
    t_statistic, p_value = stats.ttest_ind(control_data, experimental_data)
    
    # Print results for each day
    print("Day:", day)
    print("t-statistic:", t_statistic)
    print("p-value:", p_value)
    
    # Interpret the results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis - There is a significant difference in water intake between the groups at this time point.")
    else:
        print("Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.")
    print()
# Out:
# Day: 2024-02-13
# t-statistic: -1.1237046501291088
# p-value: 0.2800380891051075
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-14
# t-statistic: -0.41547809001357516
# p-value: 0.6840896806261858
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-15
# t-statistic: -0.8715444587568315
# p-value: 0.3981568940749517
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-16
# t-statistic: -0.5544041192379071
# p-value: 0.5880498939951981
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-17
# t-statistic: 0.4065725086860543
# p-value: 0.690469113407749
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-18
# t-statistic: 0.3492912213303963
# p-value: 0.7320687229223172
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-19
# t-statistic: -0.4232165775822965
# p-value: 0.6785665159915637
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-20
# t-statistic: -0.03631821340368141
# p-value: 0.9715413985501634
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-21
# t-statistic: -0.879484224284456
# p-value: 0.39398462989830974
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-22
# t-statistic: 0.32868145074371236
# p-value: 0.7472613016145473
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-23
# t-statistic: -0.6388996565066647
# p-value: 0.5332022571153622
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-24
# t-statistic: -1.3760353320056713
# p-value: 0.1904244487061476
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-25
# t-statistic: -0.5480237522254809
# p-value: 0.5923068846244703
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-26
# t-statistic: 0.55752561689945
# p-value: 0.5859729593577871
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-27
# t-statistic: 0.054941263866096546
# p-value: 0.9569616143049718
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-28
# t-statistic: -1.7168891628221608
# p-value: 0.10803066843335003
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-02-29
# t-statistic: -0.13157677787077554
# p-value: 0.8971912367323704
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-01
# t-statistic: -0.5413162253377898
# p-value: 0.596799020123134
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-02
# t-statistic: -0.6891369057229328
# p-value: 0.5019994883468328
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-03
# t-statistic: -0.4514451608052796
# p-value: 0.6585829875113385
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-04
# t-statistic: -0.33571007169301004
# p-value: 0.7420674851643141
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-05
# t-statistic: -1.753576418105237
# p-value: 0.10135907044008247
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-06
# t-statistic: -0.2565247266252229
# p-value: 0.8012769398595277
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-07
# t-statistic: -0.33418313288531576
# p-value: 0.743194722295027
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-08
# t-statistic: 0.10244389988519077
# p-value: 0.9198572283345092
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-09
# t-statistic: -1.6773505367546402
# p-value: 0.11564945868491776
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-10
# t-statistic: -3.419731381944042e-15
# p-value: 0.9999999999999973
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-11
# t-statistic: -0.3913043478260874
# p-value: 0.7014631059340948
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-12
# t-statistic: -2.5211937471062598
# p-value: 0.024444153721639928
# Reject the null hypothesis - There is a significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-13
# t-statistic: -1.294929112642243
# p-value: 0.21629361403921946
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-14
# t-statistic: 0.3475706678181008
# p-value: 0.7333326896683086
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-15
# t-statistic: 1.2725968992846242
# p-value: 0.22389056061853155
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-18
# t-statistic: -0.7295219838022501
# p-value: 0.4777114253971001
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-20
# t-statistic: 0.0
# p-value: 1.0
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-22
# t-statistic: -0.7037037037037069
# p-value: 0.493155971976737
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.
#
# Day: 2024-03-25
# t-statistic: -0.3836078769656682
# p-value: 0.7070316400686374
# Fail to reject the null hypothesis - There is no significant difference in water intake between the groups at this time point.

# %%
#t tests males - food intake
male_experimental_data = df_food_water[(df_food_water['sex'] == 'male') & (df_food_water['group'] == 'experimental')]
male_control_data = df_food_water[(df_food_water["sex"] == "male") & (df_food_water["group"] == "control")]

for day in df_food_water["date"].unique():  # Iterate over unique dates
    control_data = male_control_data[male_control_data['date'] == day]["food_intake"] 
    experimental_data = male_experimental_data[male_experimental_data['date'] == day]['food_intake']
    
    t_statistic, p_value = stats.ttest_ind(control_data, experimental_data)
    
    # Print results for each day
    print("Day:", day)
    print("t-statistic:", t_statistic)
    print("p-value:", p_value)
    
    # Interpret the results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis - There is a significant difference in food intake between the groups at this time point.")
    else:
        print("Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.")
    print()
# Out:
# Day: 2024-02-13
# t-statistic: -0.2613286875312944
# p-value: 0.7976442396508406
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-14
# t-statistic: -0.20873254938846433
# p-value: 0.8376634743078235
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-15
# t-statistic: -0.691950971492164
# p-value: 0.5002838330524217
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-16
# t-statistic: -0.7819012143768049
# p-value: 0.44729549275175495
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-17
# t-statistic: -0.2182178902360036
# p-value: 0.8304081425975807
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-18
# t-statistic: 1.4985372985306915
# p-value: 0.15620059068114328
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-19
# t-statistic: -0.5510122120527969
# p-value: 0.5903110251247481
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-20
# t-statistic: -0.8284168695794889
# p-value: 0.4213333310679389
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-21
# t-statistic: -0.9180151647723129
# p-value: 0.37415607876989254
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-22
# t-statistic: -0.45902324683735685
# p-value: 0.6532632785670744
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-23
# t-statistic: 0.48880004301486035
# p-value: 0.6325514462980497
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-24
# t-statistic: -1.1014327508553394
# p-value: 0.28928492774452624
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-25
# t-statistic: 0.22941573387056305
# p-value: 0.821863585961799
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-26
# t-statistic: -0.8669214468629978
# p-value: 0.4005998045623569
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-27
# t-statistic: -0.8227011178739819
# p-value: 0.4244697643933074
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-28
# t-statistic: -2.6164907201561625
# p-value: 0.020314398210225338
# Reject the null hypothesis - There is a significant difference in food intake between the groups at this time point.
#
# Day: 2024-02-29
# t-statistic: -0.7661407096425422
# p-value: 0.45631686991567233
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-01
# t-statistic: -0.1229584909502266
# p-value: 0.9038876878788742
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-02
# t-statistic: 0.5676712423455819
# p-value: 0.5792486306642608
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-03
# t-statistic: -0.2511236011669623
# p-value: 0.805366909791196
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-04
# t-statistic: 0.4353119350300885
# p-value: 0.6699721026954593
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-05
# t-statistic: -1.4464615178113847
# p-value: 0.17006406690878104
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-06
# t-statistic: -0.5306381349369801
# p-value: 0.6039856296976465
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-07
# t-statistic: -0.39605901719066505
# p-value: 0.698031867232167
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-08
# t-statistic: 2.000395843645635
# p-value: 0.0652408564299653
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-09
# t-statistic: -4.477275577049612
# p-value: 0.000521397246571994
# Reject the null hypothesis - There is a significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-10
# t-statistic: 0.5273305310383408
# p-value: 0.6062204544572535
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-11
# t-statistic: -1.366947811743116
# p-value: 0.1931914976055443
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-12
# t-statistic: -1.0813164858613347
# p-value: 0.2978313140608983
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-13
# t-statistic: 0.34628650983697173
# p-value: 0.7342765916807991
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-14
# t-statistic: 1.9855502476741569
# p-value: 0.06702856184878224
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-15
# t-statistic: 0.2979721758059621
# p-value: 0.7701006523803846
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-18
# t-statistic: -0.2841385731441518
# p-value: 0.7804633671383066
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-20
# t-statistic: 0.7356407923288615
# p-value: 0.47409457944757616
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-22
# t-statistic: -0.6635145607498246
# p-value: 0.5177786748245721
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
#
# Day: 2024-03-25
# t-statistic: -1.2593280578898294
# p-value: 0.22850370310995013
# Fail to reject the null hypothesis - There is no significant difference in food intake between the groups at this time point.
