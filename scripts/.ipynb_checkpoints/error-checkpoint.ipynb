# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import trompy as tp
from scipy import stats

# %%
# read in data
PATH_TO_WORKBOOK = Path("../data/")
EXCEL_WORKBOOK = "measurements_b3_2.xlsx"
rows, header = tp.metafilereader(PATH_TO_WORKBOOK / EXCEL_WORKBOOK, sheetname="metafile_niacin_2")
df = pd.DataFrame(rows, columns=header)

# %%
def get_value(row):
    if row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
        return 0
    elif row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'No':
        return 1
    elif row['sex'] == 'female' and row['diet'] == 'experimental' and row['sucrose'] == 'Yes':
        return 2
    elif row['sex'] == 'female' and row['diet'] == 'experimental' and row['sucrose'] == 'No':
        return 3
    elif row['sex'] == 'male' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
        return 4
    elif row['sex'] == 'male' and row['diet'] == 'control' and row['sucrose'] == 'No':
        return 5
    elif row['sex'] == 'male' and row['diet'] == 'experimental' and row['sucrose'] == 'Yes':
        return 6
    elif row['sex'] == 'male' and row['diet'] == 'experimental' and row['sucrose'] == 'No':
        return 7
    else:
        return -1

def tweak_df(df):
    
    return (df
            # .query("bodyweight != ''")
            .query("animal_id != 'B3201'") ##this line removes the animal removed from the study
            .query("bodyweight.notna()", engine="python")
            .astype({"sex": "category",
                     "diet": "category",
                     "date": object, 
                     "bodyweight": float,
                     "food_yesterday": float,
                     "food_intake": float,
                     "sucrose_intake": float
                     }
                    )
             .assign(groupn = lambda df_: df_.apply(get_value, axis=1))
            )
    
df = tweak_df(pd.DataFrame(rows, columns=header))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 19
#       1 def tweak_df(df):
#       3     return (df
#       4             # .query("bodyweight != ''")
#       5             .query("animal_id != 'B3201'") ##this line removes the animal removed from the study
#    (...)
#      16              .assign(groupn = lambda df_: df_.apply(get_value, axis=1))
#      17             )
# ---> 19 df = tweak_df(pd.DataFrame(rows, columns=header))
#      21 def get_value(row):
#      22     if row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
#
# Cell In[8], line 5, in tweak_df(df)
#       1 def tweak_df(df):
#       3     return (df
#       4             # .query("bodyweight != ''")
# ----> 5             .query("animal_id != 'B3201'") ##this line removes the animal removed from the study
#       6             .query("bodyweight.notna()", engine="python")
#       7             .astype({"sex": "category",
#       8                      "diet": "category",
#       9                      "date": object,
#      10                      "bodyweight": float,
#      11                      "food_yesterday": float,
#      12                      "food_intake": float,
#      13                      "sucrose_intake": float
#      14                      }
#      15                     )
#      16              .assign(groupn = lambda df_: df_.apply(get_value, axis=1))
#      17             )
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\frame.py:4943, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4941 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4942 index_resolvers = self._get_index_resolvers()
# -> 4943 column_resolvers = self._get_cleaned_column_resolvers()
#    4944 resolvers = column_resolvers, index_resolvers
#    4945 if "target" not in kwargs:
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\generic.py:659, in NDFrame._get_cleaned_column_resolvers(self)
#     656 if isinstance(self, ABCSeries):
#     657     return {clean_column_name(self.name): self}
# --> 659 return {
#     660     clean_column_name(k): Series(
#     661         v, copy=False, index=self.index, name=k, dtype=self.dtypes[k]
#     662     ).__finalize__(self)
#     663     for k, v in zip(self.columns, self._iter_column_arrays())
#     664     if not isinstance(k, int)
#     665 }
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\generic.py:660, in <dictcomp>(.0)
#     656 if isinstance(self, ABCSeries):
#     657     return {clean_column_name(self.name): self}
#     659 return {
# --> 660     clean_column_name(k): Series(
#     661         v, copy=False, index=self.index, name=k, dtype=self.dtypes[k]
#     662     ).__finalize__(self)
#     663     for k, v in zip(self.columns, self._iter_column_arrays())
#     664     if not isinstance(k, int)
#     665 }
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\series.py:493, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     490     index = ensure_index(index)
#     492 if dtype is not None:
# --> 493     dtype = self._validate_dtype(dtype)
#     495 if data is None:
#     496     index = index if index is not None else default_index(0)
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\generic.py:516, in NDFrame._validate_dtype(cls, dtype)
#     514 """validate the passed dtype"""
#     515 if dtype is not None:
# --> 516     dtype = pandas_dtype(dtype)
#     518     # a compound dtype
#     519     if dtype.kind == "V":
#
# File ~\Documents\GitHub\niacin\myenv\Lib\site-packages\pandas\core\dtypes\common.py:1666, in pandas_dtype(dtype)
#    1664     return npdtype
#    1665 elif npdtype.kind == "O":
# -> 1666     raise TypeError(f"dtype '{dtype}' not understood")
#    1668 return npdtype
#
# TypeError: dtype 'None    object
# None    object
# None    object
# dtype: object' not understood

# %%
def get_value(row):
    if row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
        return 0
    elif row['sex'] == 'female' and row['diet'] == 'control' and row['sucrose'] == 'No':
        return 1
    elif row['sex'] == 'female' and row['diet'] == 'experimental' and row['sucrose'] == 'Yes':
        return 2
    elif row['sex'] == 'female' and row['diet'] == 'experimental' and row['sucrose'] == 'No':
        return 3
    elif row['sex'] == 'male' and row['diet'] == 'control' and row['sucrose'] == 'Yes':
        return 4
    elif row['sex'] == 'male' and row['diet'] == 'control' and row['sucrose'] == 'No':
        return 5
    elif row['sex'] == 'male' and row['diet'] == 'experimental' and row['sucrose'] == 'Yes':
        return 6
    elif row['sex'] == 'male' and row['diet'] == 'experimental' and row['sucrose'] == 'No':
        return 7
    else:
        return -1

def tweak_df(df):
    # Clean column names to avoid None or whitespace issues
    df.columns = [col.strip() if isinstance(col, str) else f"Unnamed_{i}" 
                  for i, col in enumerate(df.columns)]
    
    # Ensure necessary columns exist
    required_columns = ['sex', 'diet', 'sucrose', 'animal_id', 'bodyweight']
    for col in required_columns:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")
    
    # Apply transformations
    return (df
            .query("animal_id != 'B3201'")  # Remove specific animal
            .query("bodyweight.notna()", engine="python")  # Filter rows with valid bodyweight
            .astype({
                "sex": "category",
                "diet": "category",
                "date": str,
                "bodyweight": float,
                "food_yesterday": float,
                "food_intake": float,
                "sucrose_intake": float
            })
            .assign(groupn=lambda df_: df_.apply(get_value, axis=1))
           )

# Convert rows and header into a DataFrame
df = pd.DataFrame(rows, columns=header)

# Apply the tweak_df function
try:
    df = tweak_df(df)
except Exception as e:
    print(f"Error processing DataFrame: {e}")
